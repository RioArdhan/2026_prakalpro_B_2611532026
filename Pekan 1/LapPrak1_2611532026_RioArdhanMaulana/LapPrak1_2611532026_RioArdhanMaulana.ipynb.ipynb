# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“Pengenalan python, vscode, dan koneksi ke github”**
#
# **Disusun Oleh :**
#
# **Rio Ardhan Maulana**
#
# **2611532026**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Rifky Yuliandra**
#
# <br>
#
#  <img src="images/logo unand.jpg" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum “Pengenalan Python, VSCode, dan Koneksi ke GitHub” yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Struktur Data. Praktikum ini berfokus pada pembahasan pengenalan Python, penggunaan Visual Studio Code (VSCode), serta koneksi dan penggunaan GitHub.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep dasar penggunaan Python, VSCode, dan koneksi ke GitHub pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Perkembangan teknologi informasi membuat kemampuan pemrograman menjadi salah satu keterampilan penting bagi mahasiswa di bidang teknologi. Salah satu bahasa pemrograman yang banyak digunakan untuk pembelajaran maupun pengembangan aplikasi adalah Python. Python memiliki sintaks yang sederhana dan mudah dipahami sehingga cocok digunakan oleh pemula untuk mempelajari konsep dasar pemrograman dan struktur data.
#
# Dalam proses pengembangan program, diperlukan sebuah perangkat lunak yang dapat membantu programmer dalam menulis, menjalankan, dan mengelola kode. Salah satu perangkat lunak yang banyak digunakan adalah Visual Studio Code (VS Code). VS Code merupakan editor kode yang mendukung berbagai bahasa pemrograman, termasuk Python, serta menyediakan berbagai fitur yang membantu proses pengembangan program.
#
# Selain kemampuan membuat program, pengelolaan kode juga menjadi bagian penting dalam pengembangan perangkat lunak. Git dan GitHub dapat digunakan untuk menyimpan, mengelola, dan melakukan pelacakan perubahan kode. Dengan menghubungkan project yang dibuat menggunakan VS Code dengan GitHub, program dapat disimpan secara online dan memudahkan proses pencadangan maupun kolaborasi.
#
# Oleh karena itu, praktikum ini dilakukan untuk mengenalkan dasar penggunaan Python, Visual Studio Code, serta proses menghubungkan project dengan GitHub sebagai dasar dalam pembelajaran Struktur Data.
#
# ## 1.2 Tujuan
# 1. Menambah pemahaman mengenai penggunaan Python dalam pemrograman.
# 2. Meningkatkan kemampuan dalam menggunakan VSCode untuk membuat dan mengelola program.
# 3. Mengetahui dasar penggunaan GitHub untuk menyimpan dan mengelola proyek pemrograman.
#
# ## 1.3 Manfaat
# Manfaat yang diperoleh dari praktikum ini :
# 1. Memahami dasar penggunaan Python sebagai bahasa pemrograman.
# 2. Menggunakan Visual Studio Code sebagai lingkungan pengembangan program.
# 3. Menggunakan GitHub untuk menyimpan dan mengelola source code. Pengetahuan tersebut dapat menjadi dasar untuk praktikum-praktikum Struktur Data berikutnya.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# 1. Python merupakan bahasa pemrograman tingkat tinggi yang memiliki sintaks sederhana dan mudah dipahami. Python dapat digunakan untuk membuat berbagai jenis program dan banyak digunakan dalam pembelajaran pemrograman.
# 2. Visual Studio Code merupakan code editor yang digunakan untuk menulis, mengedit, dan menjalankan program. VSCode mendukung berbagai bahasa pemrograman, termasuk Python, serta menyediakan berbagai fitur yang membantu proses pengembangan program.
# 3. GitHub merupakan platform yang digunakan untuk menyimpan dan mengelola kode program secara daring. GitHub juga dapat digunakan untuk melakukan kolaborasi dan menyimpan riwayat perubahan pada suatu proyek.
# 4. Koneksi VSCode dengan GitHub memungkinkan proyek yang dibuat melalui VSCode untuk dihubungkan dengan repository GitHub sehingga kode dapat disimpan dan dikelola secara daring.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "Alpro_B_2611532026"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Program pertama
"""
Komentar
dua baris atau lebih
pertemuan 1 pratikum alpro
"""
print("Hello World")
print()
print("program ini menghasilkan")
print("Empat baris output")
print("/\\//\\\\///\\\\\\")
print("program ini" + "di buat oleh a\n" + "Rio_Ardhan_Maulana_2611532026")

hello world

print ini menghasilkan
empat baris output
/ \\ / \\ / \\ / \\ / 
program inidibuat oleh a
Rio Ardhan Maulana_2611532026

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama sampai keenam sebagai penjelas sebuah struktur program.
# 2. Bagian ketujuh sampai terakhir menghasilkan output.
# 3. Program ini dijalankan dengan bahasa Python.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# *Soal : Membuat sebuah file program Python bebas dengan nama tugas1_nim.py.*

# %%
nama = Rio Ardhan Maulana
nim = 2611532026
kelas = Alpro B
jenis_kelamin = "Laki-laki"
agama = "islam"
hobi = "membaca buku, berolahraga, bermain game"



print("========================================")
print("          DATA DIRI MAHASISWA")
print("========================================")
print("Nama          :", nama)
print("NIM           :", nim)
print("Kelas         :", kelas)
print("Jenis Kelamin :", jenis_kelamin)
print("Agama         :", agama)
print("Hobi          :", hobi)
print("========================================")
print("python sangat menyenangkan!")

# %% [markdown]
# Output :
#
# **Penjelasan :** Program di atas merupakan contoh sederhana penggunaan bahasa pemrograman Python untuk menampilkan data diri mahasiswa. Program menggunakan beberapa variabel untuk menyimpan informasi yang akan ditampilkan.
#
# Variabel nama digunakan untuk menyimpan nama mahasiswa, sedangkan variabel nim digunakan untuk menyimpan Nomor Induk Mahasiswa. Variabel kelas digunakan untuk menyimpan informasi kelas mahasiswa.
#
# Selain itu, program memiliki variabel jenis_kelamin untuk menyimpan informasi jenis kelamin, variabel agama untuk menyimpan agama, dan variabel hobi untuk menyimpan kegiatan atau aktivitas yang disukai mahasiswa.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa Python merupakan bahasa pemrograman yang memiliki sintaks sederhana dan dapat digunakan untuk mempelajari berbagai konsep pemrograman serta Struktur Data.
#
# Visual Studio Code dapat digunakan sebagai editor untuk membuat dan menjalankan program Python. VS Code juga menyediakan terminal dan integrasi Git yang membantu proses pengembangan project.
#
# Git dan GitHub dapat digunakan untuk mengelola serta menyimpan source code. Project Python yang dibuat secara lokal dapat dihubungkan dengan repository GitHub melalui beberapa perintah Git seperti git init, git add, git commit, dan git push.
#
# Dengan praktikum ini, mahasiswa memperoleh dasar penggunaan Python, Visual Studio Code, Git, dan GitHub yang dapat digunakan untuk mendukung praktikum Struktur Data selanjutnya.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation, "Python Documentation," Python, [Online]. Tersedia: https://docs.python.org/3/. [Diakses 6 September 2026].
#
# [2] Microsoft, "Visual Studio Code Documentation," Visual Studio Code, [Online]. Tersedia: https://code.visualstudio.com/docs. [Diakses 6 September 2026].
#
# [3] GitHub, "GitHub Documentation," GitHub, [Online]. Tersedia: https://docs.github.com/. [Diakses 6 September 2026].
