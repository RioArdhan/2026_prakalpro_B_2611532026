# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“Operator Pada Python”**
#
# **Disusun Oleh :**
#
# **Rio Ardhan Maulana**
#
# **2611532026**
#
# **Dosen Pengampu:**
#
# **Dr. Ir WAHYUDI, ST., MT.**
#
# **Asisten Praktikum:**
#
# **Rifky Yuliandra**
#
# <br>
#
#  <img src="logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur kehadirat Allah SWT yang telah memberikan rahmat dan karunia-Nya sehingga penulis dapat menyelesaikan laporan praktikum yang berjudul “Operator pada Python” dengan baik dan tepat waktu.
#
# Laporan ini disusun untuk memenuhi salah satu tugas praktikum dalam mata kuliah Pemrograman. Praktikum ini membahas berbagai jenis operator yang terdapat dalam bahasa pemrograman Python, meliputi operator aritmatika, assignment, perbandingan, logika, membership, identity, dan bitwise. Melalui praktikum ini, penulis dapat memahami fungsi serta penggunaan berbagai operator tersebut dalam pembuatan program Python.
#
# Penulis menyadari bahwa dalam penyusunan laporan ini masih terdapat kekurangan, baik dari segi penulisan maupun pembahasan. Oleh karena itu, penulis mengharapkan kritik dan saran yang membangun agar laporan selanjutnya dapat menjadi lebih baik.
#
# Penulis mengucapkan terima kasih kepada dosen pengampu serta semua pihak yang telah memberikan bantuan dan bimbingan selama pelaksanaan praktikum hingga penyusunan laporan ini. Semoga laporan ini dapat memberikan manfaat dan menambah pengetahuan bagi penulis maupun pembaca.
#
# Padang, 2026
#
# Rio Ardhan Maulana

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
#  Perkembangan teknologi informasi yang semakin pesat membuat kemampuan dalam bidang pemrograman menjadi salah satu keterampilan yang penting untuk dipelajari. Pemrograman digunakan untuk membuat berbagai aplikasi dan sistem yang dapat membantu menyelesaikan pekerjaan secara lebih cepat dan efisien. Salah satu bahasa pemrograman yang banyak digunakan untuk pembelajaran maupun pengembangan berbagai aplikasi adalah Python.
#
# Python merupakan bahasa pemrograman yang memiliki sintaks sederhana dan mudah dipahami, sehingga sesuai digunakan oleh pemula untuk mempelajari konsep dasar pemrograman. Dalam proses pembuatan program, terdapat berbagai komponen dasar yang perlu dipahami, salah satunya adalah operator. Operator digunakan untuk melakukan berbagai operasi terhadap data atau variabel sehingga program dapat menghasilkan keluaran sesuai dengan kebutuhan.
#
# Python memiliki beberapa jenis operator, antara lain operator aritmatika, assignment, perbandingan, logika, membership, identity, dan bitwise. Operator aritmatika digunakan untuk melakukan perhitungan matematika, operator assignment digunakan untuk memberikan atau mengubah nilai variabel, sedangkan operator perbandingan digunakan untuk membandingkan dua nilai. Selain itu, operator logika digunakan untuk mengolah kondisi, operator membership untuk memeriksa keanggotaan suatu data, operator identity untuk memeriksa identitas objek, dan operator bitwise untuk melakukan operasi pada representasi biner.
#
# Pemahaman mengenai berbagai jenis operator tersebut sangat penting karena operator merupakan bagian yang sering digunakan dalam pembuatan program Python. Dengan memahami fungsi dan cara penggunaan setiap operator, seseorang dapat membuat program yang lebih terstruktur serta mampu melakukan proses pengolahan data dan pengambilan keputusan dengan tepat. Oleh karena itu, praktikum mengenai operator pada Python dilakukan agar mahasiswa dapat memahami konsep dasar operator serta mampu menerapkannya secara langsung dalam program sederhana.
#
#
#
# ## 1.2 Tujuan
# 1. Memahami konsep dan fungsi berbagai jenis operator pada bahasa pemrograman Python.
# 2. Mampu menggunakan operator aritmatika untuk melakukan perhitungan dalam program.
# 3. Mampu menggunakan operator assignment untuk memberikan dan memperbarui nilai variabel.
# 4. Mampu menggunakan operator perbandingan untuk menghasilkan nilai Boolean.
# 5. Mampu menggunakan operator logika untuk menggabungkan beberapa kondisi.
# 6. Mampu menggunakan operator membership untuk memeriksa keberadaan suatu nilai dalam sebuah data.
# 7. Mampu memahami perbedaan operator identity dengan operator perbandingan.
# 8. Mampu menggunakan operator bitwise untuk mengolah nilai dalam bentuk biner.
# 9. Mampu mengintegrasikan berbagai jenis operator ke dalam sebuah program untuk menyelesaikan studi kasus transaksi.
#
# ## 1.3 Manfaat
# 1. Menambah pemahaman mengenai berbagai jenis operator dalam Python.
# 2. Meningkatkan kemampuan dalam melakukan operasi dan pengolahan data menggunakan Python.
# 3. Melatih kemampuan dalam menggunakan kondisi dan logika pada sebuah program.
# 4. Memahami penerapan operator bitwise dalam pengolahan status berbasis biner.
# 5. Meningkatkan kemampuan dalam menggabungkan beberapa operator untuk menyelesaikan suatu permasalahan.
# 6. Melatih kemampuan dalam membuat dan menjelaskan program Python secara terstruktur.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# ### 2.1.1 Pengertian Operator
#
# Operator adalah simbol atau kata khusus yang digunakan untuk melakukan operasi terhadap satu atau lebih operand. Operand dapat berupa nilai, variabel, maupun objek. Dalam Python, operator digunakan untuk melakukan berbagai proses seperti perhitungan, perbandingan, penggabungan kondisi, hingga manipulasi nilai biner.
#
# Beberapa jenis operator yang digunakan dalam praktikum ini antara lain operator aritmatika, assignment, perbandingan, logika, membership, identity, dan bitwise.
#
# ### 2.1.2 Operator Aritmatika
#
# Operator aritmatika digunakan untuk melakukan operasi matematika. Beberapa operator aritmatika yang terdapat pada Python yaitu:
#
# Operator	Fungsi
# +	Penjumlahan
# -	Pengurangan
# *	Perkalian
# /	Pembagian
# //	Pembagian bulat
# %	Sisa pembagian atau modulus
# **	Perpangkatan
#
# Dalam program transaksi, operator aritmatika dapat digunakan untuk menghitung besar diskon, total pembayaran, rata-rata harga barang, dan sisa pembagian.
#
# ### 2.1.3 Operator Assignment
#
# Operator assignment digunakan untuk memberikan atau memperbarui nilai pada sebuah variabel. Operator dasar assignment adalah =.
# Python juga menyediakan augmented assignment, yaitu operator yang menggabungkan operasi aritmatika dengan assignment.
#
# Contohnya:
#
# nilai_3003 = 10
# nilai_3003 += 5
#
# Setelah operasi tersebut, nilai nilai_3003 menjadi 15.
#
# Beberapa augmented assignment yang umum digunakan yaitu +=, -=, *=, /=, dan lainnya.
#
# ### 2.1.4 Operator Perbandingan
#
# Operator perbandingan digunakan untuk membandingkan dua nilai. Hasil dari operator perbandingan berupa nilai Boolean, yaitu True atau False.
#
# Beberapa operator perbandingan antara lain:
#
# Operator	Fungsi
# ==	Sama dengan
# !=	Tidak sama dengan
# >	Lebih besar
# <	Lebih kecil
# >=	Lebih besar atau sama dengan
# <=	Lebih kecil atau sama dengan
#
# Dalam program transaksi, operator perbandingan digunakan untuk menentukan apakah total belanja telah mencapai batas minimum dan apakah jumlah barang telah memenuhi persyaratan.
#
# ### 2.1.5 Operator Logika
#
# Operator logika digunakan untuk menggabungkan atau membalik kondisi Boolean. Python memiliki tiga operator logika utama, yaitu and, or, dan not.
#
# and menghasilkan True jika seluruh kondisi bernilai True.
# or menghasilkan True jika setidaknya salah satu kondisi bernilai True.
# not membalik nilai Boolean.
#
# Contohnya:
#
# member_2026 = True
# belanja_2026 = True
#
# hasil_2026 = member_3003 and belanja_2026
#
# Hasil dari operasi tersebut adalah True.
#
# ### 2.1.6 Operator Membership
#
# Operator membership digunakan untuk memeriksa apakah suatu nilai terdapat di dalam suatu koleksi data seperti list, tuple, atau string.
#
# Operator membership yang digunakan dalam Python adalah:
#
# in
# not in
#
# Contohnya:
#
# kode_2026 = "HEMAT10"
# daftar_2026 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]
#
# hasil_2026 = kode_2026 in daftar_2026
#
# Hasilnya adalah True karena kode HEMAT10 terdapat di dalam daftar.
#
# ### 2.1.7 Operator Identity
#
# Operator identity digunakan untuk memeriksa apakah dua variabel merujuk pada objek yang sama.
#
# Operator identity terdiri dari:
#
# is
# is not
#
# Operator is membandingkan identitas objek, sedangkan == membandingkan nilai atau isi objek.
#
# Sebagai contoh, dua list dapat memiliki isi yang sama tetapi merupakan dua objek yang berbeda. Oleh karena itu, kedua list tersebut dapat menghasilkan True ketika dibandingkan dengan ==, tetapi False ketika dibandingkan menggunakan is.
#
# ### 2.1.8 Operator Bitwise
#
# Operator bitwise digunakan untuk melakukan operasi terhadap bilangan dalam representasi biner. Operator ini dapat digunakan untuk menggabungkan maupun memeriksa status tertentu yang direpresentasikan menggunakan bit.
#
# Beberapa operator bitwise yang digunakan dalam praktikum adalah:
#
# Operator	Fungsi
# &	AND bitwise
# |	OR bitwise
# ^	XOR bitwise
# <<	Left shift
# >>	Right shift
#
# Pada studi kasus transaksi, setiap kondisi pelanggan direpresentasikan menggunakan nilai bit:
#
# Nilai Bit	Kondisi
# 0001	Pelanggan merupakan member
# 0010	Total belanja ≥ Rp200.000
# 0100	Jumlah barang ≥ 3
# 1000	Kode promo tersedia
#
# Operator OR digunakan untuk menggabungkan beberapa kondisi menjadi satu kode status. Operator AND digunakan untuk memeriksa kondisi tertentu dari kode status. Sementara itu, XOR dapat digunakan untuk membandingkan perbedaan antara kode transaksi dan kode referensi.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "aritmatika_2611532026"

# %%
# Buat file dengan nama aritmatika_NIM_py
# Buat program untuk operator aritmatika dalam Python
# Nama variabel ditambah 4 digit nim terakhir contoh: a_1234
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer

angka1_2026 = int(input("Input angka-1: "))
angka2_2026 = int(input("Input angka-2: "))

# Penjumlahan
hasil_2026 = angka1_2026 + angka2_2026
print("\nOperator Penjumlahan")
print("Hasil =", hasil_2026)

# Pengurangan
hasil_2026 = angka1_2026 - angka2_2026
print("\nOperator Pengurangan")
print("Hasil =", hasil_2026)

# Perkalian
hasil_2026 = angka1_2026 * angka2_2026
print("\nOperator Perkalian")
print("Hasil =", hasil_2026)

# Pembagian
if angka2_2026 != 0:
    hasil_2026 = angka1_2026 / angka2_2026
    print("\nOperator Pembagian")
    print("Hasil =", hasil_2026)

    hasil_2026 = angka1_2026 // angka2_2026
    print("\nOperator Pembagian Bulat")
    print("Hasil =", hasil_2026)

    hasil_2026 = angka1_2026 % angka2_2026
    print("\nOperator Sisa Bagi")
    print("Hasil =", hasil_2026)
else:
    print("Angka kedua tidak boleh bernilai 0.")

# Pangkat
hasil_2026 = angka1_2026 ** angka2_2026
print("\nOperator Pangkat")
print("Hasil =", hasil_2026)
# Out:
# Operator penjumlahan
# hasil = 15
#
# Operator pengurangan
# hasil = 5
#
# Operator perkalian
# hasil = 50
#
# Operator pembagian
# hasil = 2.0
#
# Operator pembagian bulat
# hasil = 2
#
# Operator sisa bagi
# hasil = 0
#
# Operator pangkat
# hasil = 100000

# %% [markdown]
# **Penjelasan :**
#
# 1. Bagian 1 sampai 2 berfungsi untuk membuat variabel `angka1_2026` dan `angka2_2026` yang digunakan untuk menyimpan dua bilangan yang dimasukkan oleh pengguna. Fungsi `int(input())` digunakan untuk menerima input dalam bentuk bilangan bulat.
#
# 2. Bagian 4 sampai 6 berfungsi untuk melakukan operasi penjumlahan menggunakan operator `+`. Hasil penjumlahan dari `angka1_2026` dan `angka2_2026` disimpan ke dalam variabel `hasil_2026`, kemudian ditampilkan menggunakan fungsi `print()`.
#
# 3. Bagian 8 sampai 10 berfungsi untuk melakukan operasi pengurangan menggunakan operator `-`. Nilai `angka2_2026` dikurangi dari `angka1_2026`, kemudian hasilnya disimpan ke dalam variabel `hasil_2026` dan ditampilkan ke layar.
#
# 4. Bagian 12 sampai 14 berfungsi untuk melakukan operasi perkalian menggunakan operator `*`. Nilai `angka1_2026` dikalikan dengan `angka2_2026`, kemudian hasilnya disimpan ke dalam variabel `hasil_2026` dan ditampilkan.
#
# 5. Bagian 16 sampai 17 berfungsi untuk melakukan pengecekan menggunakan operator perbandingan `!=`. Kondisi tersebut digunakan untuk memastikan bahwa `angka2_2026` tidak bernilai 0 sebelum dilakukan operasi pembagian.
#
# 6. Bagian 18 sampai 20 berfungsi untuk melakukan operasi pembagian menggunakan operator `/`. Nilai `angka1_2026` dibagi dengan `angka2_2026`, kemudian hasilnya disimpan ke dalam variabel `hasil_2026` dan ditampilkan.
#
# 7. Bagian 22 sampai 24 berfungsi untuk melakukan operasi pembagian bulat menggunakan operator `//`. Operator tersebut menghasilkan hasil pembagian tanpa menyertakan bagian desimal, kemudian hasilnya ditampilkan.
#
# 8. Bagian 26 sampai 28 berfungsi untuk melakukan operasi sisa bagi atau modulus menggunakan operator `%`. Operator tersebut digunakan untuk mendapatkan sisa hasil pembagian antara `angka1_2026` dan `angka2_2026`.
#
# 9. Bagian 29 sampai 30 berfungsi untuk memberikan pesan kepada pengguna apabila `angka2_2026` bernilai 0. Hal ini dilakukan karena angka 0 tidak dapat digunakan sebagai pembagi.
#
# 10. Bagian 32 sampai 34 berfungsi untuk melakukan operasi perpangkatan menggunakan operator `**`. Nilai `angka1_2026` dipangkatkan dengan `angka2_2026`, kemudian hasilnya disimpan ke dalam variabel `hasil_2026` dan ditampilkan ke layar.

# %% [markdown]
# ### 2.2.2 Program "assignment_2611532026"

# %%
# Buat file dengan nama assignment_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator assignment dalam Python

angka1_2026 = int(input("Input angka-1: "))
angka2_2026 = int(input("Input angka-2: "))

print("\nNilai awal angka1_2026 =", angka1_2026)
print("Nilai angka2_2026 =", angka2_2026)

# Assignment biasa
hasil_2026 = angka1_2026
print("\nAssignment biasa (=)")
print("Hasil =", hasil_2026)

# Assignment penambahan
hasil_2026 = angka1_2026
hasil_2026 += angka2_2026
print("\nAssignment pnambahan (+=)")
print("Hasil =", hasil_2026)

# Assignment pengurangan
hasil_2026 = angka1_2026
hasil_2026 -= angka2_2026
print("\nAssignment pengurangan (-=)")
print("Hasil =", hasil_2026)
      
# Assignment perkalian
hasil_2026 = angka1_2026
hasil_2026 *= angka2_2026
print("nAssignment perkalian (*=)")
print("Hasil =", hasil_2026)

# Assignment pembagian, pembagian bulat, dan sisa bagi
if angka2_2026 != 0:
    hasil_2026 = angka1_2026
    hasil_2026 /= angka2_2026
    print("nAssignment pembagian (/=)")
    print("Hasil =", hasil_2026)
    # Operator tambahan
    hasil_2026 = angka1_2026
    hasil_2026//= angka2_2026
    print("\nAssignment pembagian bulat (//=)")
    print("Hasil =", hasil_2026)
    hasil_2026 = angka1_2026
    hasil_2026 %= angka2_2026
    print("\nAssignment sisa bagi (%=)")
    print("Hasil =", hasil_2026)
else:
    print("\nPembagian tidak dapat dilakukan.")
    print("Angka kedua tidak boleh bernilai 0.")

    # Operator tambahan: assignment perpangkatan
    hasil_2026 = angka2_2026
    hasil_2026 **= angka2_2026
    print("\nAssignment perpangkatan (**=)")
    print("Hasil =", hasil_2026)

# %% [markdown]
# **Penjelasan :**
#
# 1. **Bagian 1 sampai 5** berfungsi untuk menerima dua angka dari pengguna dan menampilkan nilai awal dari variabel `angka1_2026` dan `angka2_2026`.
#
# 2. **Bagian 7 sampai 10** berfungsi untuk melakukan assignment biasa menggunakan operator `=` dengan menyimpan nilai `angka1_2026` ke dalam variabel `hasil_2026`, kemudian menampilkan hasilnya.
#
# 3. **Bagian 12 sampai 16** berfungsi untuk melakukan assignment penambahan menggunakan operator `+=`, yaitu menambahkan nilai `angka2_2026` ke dalam nilai `hasil_2026`.
#
# 4. **Bagian 18 sampai 22** berfungsi untuk melakukan assignment pengurangan menggunakan operator `-=`, yaitu mengurangi nilai `hasil_2026` dengan nilai `angka2_2026`.
#
# 5. **Bagian 24 sampai 28** berfungsi untuk melakukan assignment perkalian menggunakan operator `*=`, yaitu mengalikan nilai `hasil_2026` dengan nilai `angka2_2026`.
#
# 6. **Bagian 30 sampai 31** berfungsi untuk menentukan kondisi pembagian dengan memeriksa apakah `angka2_2026` tidak sama dengan 0 menggunakan operator `!=`.
#
# 7. **Bagian 32 sampai 35** berfungsi untuk melakukan assignment pembagian menggunakan operator `/=`, yaitu membagi nilai `hasil_2026` dengan `angka2_2026` dan menampilkan hasilnya.
#
# 8. **Bagian 37 sampai 41** berfungsi untuk melakukan assignment pembagian bulat menggunakan operator `//=`, yaitu membagi nilai `hasil_2026` dengan `angka2_2026` dan menghasilkan nilai pembagian tanpa angka desimal.
#
# 9. **Bagian 42 sampai 45** berfungsi untuk melakukan assignment sisa bagi menggunakan operator `%=`, yaitu mencari sisa hasil pembagian `hasil_2026` dengan `angka2_2026`.
#
# 10. **Bagian 46 sampai 48** berfungsi untuk menangani kondisi ketika `angka2_2026` bernilai 0. Program akan menampilkan pesan bahwa pembagian tidak dapat dilakukan.
#
# 11. **Bagian 50 sampai 54** berfungsi untuk melakukan assignment perpangkatan menggunakan operator `**=`, yaitu memangkatkan nilai `hasil_2026` dengan `angka2_2026` dan menampilkan hasilnya.

# %% [markdown]
# ### 2.2.3 Program "perbandingan_2611532026"

# %%
# Buat file dengan nama perbandingan_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_2026
# Program ini menggunakan fungsi input()
# Nilai yang dimasukkan akan dikonversi menjadi tipe data integer
# Program operator perbandingan dalam Python

angka1_2026 = int(input("Input angka-1: "))
angka2_2026 = int(input("Input angka-2: "))

# Lebih besar dari
hasil_2026 = angka1_2026 > angka2_2026
print("\nOperator lebih besar dari")
print("anka1_2026 > angka2_2026 =", hasil_2026)

# Lebih kecil dari
hasil_2026 = angka1_2026 < angka2_2026
print("\nOperator lebih kecil dari")
print("angka1_2026 < angka2_2026 =", hasil_2026)

# Lebih besar dari atau sama dengan
hasil_2026 = angka1_2026 >= angka2_2026
print("\nOperator lebih besar dari atau sama dengan")
print("angka1_2026 >= angka2_2026 =", hasil_2026)

# Lebih kecil dari atau sama dengan
hasil_2026 = angka1_2026 <= angka2_2026
print("\nOperator lebih kecil atau sama dengan")
print("angka1_2026 <= angka2_2026 =", hasil_2026)

# Sama dengan
hasil_2026 = angka1_2026 == angka2_2026
print("\nOperator sama dengan")
print("angka1_2026 == angka2_2026 =", hasil_2026)

# Tidak sama dengan
hasil_2026 = angka1_2026 != angka1_2026
print("\nOperator tidak sama dengan")
print("angka1_2026 != angka2-2026 =", hasil_2026)

# Tambahan: perbandingan berantai dalam Python
hasil_2026 = 0 < angka1_2026 < 100
print("\n Perbandingan berantai")
print("0 < angka1_2026 , 100 =", hasil_2026)

hasil_2026 = 0 < angka2_2026
print("0 < angka2_2026 < 100 =", hasil_2026)

# %% [markdown]
# **Penjelasan :**
#
# 1. **Bagian 1 sampai 2** berfungsi untuk menerima dua angka dari pengguna dan menyimpannya ke dalam variabel `angka1_2026` dan `angka2_2026`.
#
# 2. **Bagian 4 sampai 7** berfungsi untuk membandingkan apakah `angka1_2026` lebih besar dari `angka2_2026` menggunakan operator `>` dan menampilkan hasil perbandingannya.
#
# 3. **Bagian 9 sampai 12** berfungsi untuk membandingkan apakah `angka1_2026` lebih kecil dari `angka2_2026` menggunakan operator `<` dan menampilkan hasilnya.
#
# 4. **Bagian 14 sampai 17** berfungsi untuk membandingkan apakah `angka1_2026` lebih besar dari atau sama dengan `angka2_2026` menggunakan operator `>=`.
#
# 5. **Bagian 19 sampai 22** berfungsi untuk membandingkan apakah `angka1_2026` lebih kecil dari atau sama dengan `angka2_2026` menggunakan operator `<=`.
#
# 6. **Bagian 24 sampai 27** berfungsi untuk membandingkan apakah `angka1_2026` sama dengan `angka2_2026` menggunakan operator `==`.
#
# 7. **Bagian 29 sampai 32** berfungsi untuk membandingkan apakah `angka1_2026` tidak sama dengan `angka2_2026` menggunakan operator `!=`.
#
# 8. **Bagian 34 sampai 37** berfungsi untuk melakukan perbandingan berantai dengan kondisi `0 < angka1_2026 < 100`, kemudian menyimpan dan menampilkan hasilnya.
#
# 9. **Bagian 38 sampai 40** berfungsi untuk melakukan perbandingan berantai dengan kondisi `0 < angka2_2026 < 100`, kemudian menyimpan dan menampilkan hasilnya.

# %% [markdown]
# ### 2.2.4 Program "logika_2611532026"

# %%
# Buat file dengan nama logika_NIM.py
# Nama variabel ditambah 4 digit nim terakhir conto: a1_1234
# Program ini mengguankan fungsi input()
# Prgram operator logika dalam Python

# Memasukkan nilai Boolean
# Input tidak peka terhadap huruf besar dan kecil
a1_2026 = input("Input nilai boolean-1 (true/false): ").strip().lower == "true"
a2_2026 = input("Input nilai boolean-2 (true/false): ").strip().lower == "true"

print("\nA1_2026 =", a1_2026)
print("\nA2_2026 =", a2_2026)

# Konjungsi: bernilai true jika kedunya true
hasil_2026 = a1_2026 and a2_2026
print("\nKonjungsi (AND)")
print("A1_2026 and A2_2026 =", hasil_2026)

# Disjungsi: bernilai true jika salah satunya true
hasil_2026 = a1_2026 or a2_2026
print("\nDisjungsi (OR)")
print("A1_206 or A2_2026 =", hasil_2026)

# Negasi A1_2026: membaik nilai A1
hasil_2026 = not a1_2026
print("\nNegasi A1_2026 (NOT)")
print("not A1_2026 =", hasil_2026)

# Negasi A2: membaik nilai A2
hasil_2026 = not a2_2026
print("\nNegasi A2_2026 (NOT)")
print("not A2_2026 =", hasil_2026)

# XOR: bernilai true jika kedua nilai berbeda
hasil_2026 = a1_2026 != a2_2026
print("\nDisjungsi Eksklusif (XOR)")
print("A1_2026 XOR A2_2026 =", hasil_2026)
# Out:
# A1 =  True
# A2 =  False
#
# Konjungsi (AND)
# A1 and A2 = False
#
# Disjungsi (OR)
# A1 or A2 = True
#
# Negasi A1 (NOT)
# not A1 = False
#
# Negasi A2 (NOT)
# not A2 = True
#
# Disjungsi eksklusif (XOR)
# A1 XOR A2 = True

# %% [markdown]
# **Penjelasan :**
#
# 1. **Bagian 1 sampai 5** berfungsi untuk menerima dua nilai boolean dari pengguna, mengubah input menjadi nilai `True` atau `False`, kemudian menampilkan nilai dari `a1_2026` dan `a2_2026`.
#
# 2. **Bagian 7 sampai 10** berfungsi untuk melakukan operasi konjungsi menggunakan operator `and`. Hasil akan bernilai `True` apabila kedua nilai `a1_2026` dan `a2_2026` bernilai `True`.
#
# 3. **Bagian 12 sampai 15** berfungsi untuk melakukan operasi disjungsi menggunakan operator `or`. Hasil akan bernilai `True` apabila salah satu atau kedua nilai bernilai `True`.
#
# 4. **Bagian 17 sampai 20** berfungsi untuk melakukan operasi negasi terhadap nilai `a1_2026` menggunakan operator `not`, sehingga nilai `True` akan menjadi `False` dan sebaliknya.
#
# 5. **Bagian 22 sampai 25** berfungsi untuk melakukan operasi negasi terhadap nilai `a2_2026` menggunakan operator `not`, sehingga nilai boolean yang dimasukkan akan dibalik.
#
# 6. **Bagian 27 sampai 30** berfungsi untuk melakukan operasi XOR atau disjungsi eksklusif dengan membandingkan `a1_2026` dan `a2_2026` menggunakan operator `!=`. Hasil akan bernilai `True` apabila kedua nilai boolean berbeda.

# %% [markdown]
# ### 2.2.5 Program "lainnya_2611532026"

# %%
# Buat file dengan nama lainnya_NIM.py
# Nama variabel ditambah 4 digit nim terakhir conto: angka1_1234
# Program ini mengguanakan fungsi input()
# Program operator keanggotaan dan identitas

print("==================================")
print("1. OPERTOR KEANGGOTAAN")
print("==================================")

# Input beberapa data yang dipisahkan dengan koma
input_data_2026 = input("Masukkan beberapa angka, pisahkan dengan koma: ")

# Mengubah input menjadi list integer
data_2026 = [int(angka.strip()) for angka in input_data_2026.split(",")]

nilai_dicari_2026 = int(input("Masukkan angka yang ingin dicari: "))

# Operator In
hasil_2026 = nilai_dicari_2026 in data_2026
print("\nOperator keanggotaan IN")
print(nilai_dicari_2026, "in", data_2026, "=", hasil_2026)

# Operator Not In
hasil_2026 = nilai_dicari_2026 not in data_2026
print("\nOperator keanggotaan NOT IN")
print(nilai_dicari_2026, "not in", data_2026, "=", hasil_2026)


print("\n==================================")
print("2. OPERATOR IDENTITAS")
print("==================================")

# objek1 menggunakan list dari input pengguna
objek1_20226 = data_2026

# objek2 menggunakan list dari input pengguna
objek2_2026 = objek1_2026

# objek3 memiliki isi sama, tetapi merupakan objek baru
objek3_2026 = data_2026.copy()

print("objek1_2026 =", objek1_2026)
print("objek2_2026 =", objek2_2026)
print("objek3_2026 =", objek3_2026)

# Operator Is
hasil_2026 = objek1_2026 is objek2_2026
print("\nOperator identitas IS")
print("objek1_2026 is objek2_2026 =", hasil_2026)

# Operator Is Not
hasil_2026 = objek1_2026 is not objek3_2026
print("\nOperator identitas IS NOT")
print("objek1_2026 is not objek3_2026 =", hasil_2026)

# Membandingkan identitas dan nilai
print("\nMembandingkan identitas dan nilai:")
print("objek1_2026 is objek3_2026 =", objek1_2026 is objek3_2026)
print("objek1_2026 == objek3_2026 =", objek1_2026 == objek3_2026)

# %% [markdown]
# **Penjelasan :**
#
# 1. **Bagian 1 sampai 3** berfungsi untuk menampilkan judul program mengenai operator keanggotaan.
#
# 2. **Bagian 5 sampai 6** berfungsi untuk menerima beberapa angka dari pengguna yang dipisahkan dengan tanda koma dan menyimpannya ke dalam variabel `input_data_2026`.
#
# 3. **Bagian 8 sampai 8** berfungsi untuk mengubah data yang dimasukkan pengguna menjadi list berisi bilangan integer. Fungsi `split(",")` digunakan untuk memisahkan data berdasarkan koma, sedangkan `strip()` digunakan untuk menghilangkan spasi.
#
# 4. **Bagian 10 sampai 10** berfungsi untuk menerima angka yang ingin dicari oleh pengguna dan menyimpannya ke dalam variabel `nilai_dicari_2026`.
#
# 5. **Bagian 12 sampai 15** berfungsi untuk menggunakan operator keanggotaan `in` untuk memeriksa apakah `nilai_dicari_2026` terdapat di dalam `data_2026`, kemudian menampilkan hasil pemeriksaannya.
#
# 6. **Bagian 17 sampai 20** berfungsi untuk menggunakan operator keanggotaan `not in` untuk memeriksa apakah `nilai_dicari_2026` tidak terdapat di dalam `data_2026`, kemudian menampilkan hasilnya.
#
# 7. **Bagian 22 sampai 24** berfungsi untuk menampilkan judul bagian operator identitas.
#
# 8. **Bagian 26 sampai 27** berfungsi untuk membuat `objek1_2026` yang merujuk pada list `data_2026`.
#
# 9. **Bagian 29 sampai 30** berfungsi untuk membuat `objek2_2026` yang merujuk pada objek yang sama dengan `objek1_2026`.
#
# 10. **Bagian 32 sampai 33** berfungsi untuk membuat `objek3_2026` sebagai objek list baru dengan isi yang sama seperti `data_2026` menggunakan fungsi `copy()`.
#
# 11. **Bagian 35 sampai 37** berfungsi untuk menampilkan nilai dari `objek1_2026`, `objek2_2026`, dan `objek3_2026`.
#
# 12. **Bagian 39 sampai 42** berfungsi untuk menggunakan operator identitas `is` untuk memeriksa apakah `objek1_2026` dan `objek2_2026` merupakan objek yang sama, kemudian menampilkan hasilnya.
#
# 13. **Bagian 44 sampai 47** berfungsi untuk menggunakan operator identitas `is not` untuk memeriksa apakah `objek1_2026` dan `objek3_2026` merupakan objek yang berbeda, kemudian menampilkan hasilnya.
#
# 14. **Bagian 49 sampai 52** berfungsi untuk membandingkan identitas dan nilai dari `objek1_2026` dan `objek3_2026`. Operator `is` digunakan untuk membandingkan identitas objek, sedangkan operator `==` digunakan untuk membandingkan isi atau nilai kedua objek.

# %% [markdown]
# ### 2.2.6 Program "bitwise_2611532026"

# %%
# Buat file dengan nama bitwise_NIM.py
# Nama variabel ditambah 4 digit nim terakhir contoh: angka1_1234
# Program ini menggunakan fungsi input()

print("\n==================================")
print("3. OPERATOR BITWISE")
print("==================================")

angka1_2026 = int(input("Masukkan angka bitwise-1: "))
angka2_2026 = int(input("Masukkan angka bitwise-2: "))

print("\nAngka dalam bentuk desimal dan biner:")
print("Angka 1:", angka1_2026, "-| biner", bin(angka1_2026))
print("Angka 2:", angka2_2026, "-| biner", bin(angka2_2026))

# Bitwise AND
hasil_2026 = angka1_2026 & angka2_2026
print("\nBitwise AND (&)")
print(angka1_2026, "&", angka2_2026, "=", hasil_2026)
print("Biner hasil =", bin(hasil_2026))
print("Biner hasil (8 bit) =", format(hasil_2026, '08b'))

# Bitwise OR
hasil_2026 = angka1_2026 | angka2_2026
print("\nBitwise OR (|)")
print(angka1_2026, "|", angka2_2026, "=", hasil_2026)
print("Biner hasil =", bin(hasil_2026))
print("Biner hasil (8 bit) =", format(hasil_2026, "08b"))

# Bitwise XOR
hasil_2026 = angka1_2026 ^ angka2_2026
print("\nBitwise XOR (^)")
print(angka1_2026, "^", angka2_2026, "=", hasil_2026)
print("Biner hasil =", bin(hasil_2026))
print("Biner hasil (8 bit) =", format(hasil_2026, '08b'))

# Bitwise NOT
hasil_2026 = ~angka1_2026
print("\nBitwise NOT (~)")
print("~", angka1_2026, "=", hasil_2026)
print("Biner hasil =", bin(hasil_2026))
print("Biner hasil (8 bit) =", format(hasil_2026, '08b'))

# Bitwise geser kiri
jumlah_geser_2026 = int(input("\nMasukkan jumlah pergeseran bit: "))

hasil_2026 = angka1_2026 << jumlah_geser_2026
print("\nBitwise Geser Kiri (<<)")
print(angka1_2026, "<<", jumlah_geser_2026, "=", hasil_2026)
print("Biner hasil =", bin(hasil_2026))
print("Biner hasil (8 bit) =", format(hasil_2026, '08b'))

# Bitwise geser kanan
hasil_2026 = angka1_2026 >> jumlah_geser_2026
print("\nBitwise Geser Kanan (>>)")
print(angka1_2026, ">>", jumlah_geser_2026, "=", hasil_2026)
print("Biner hasil =", bin(hasil_2026))
print("Biner hasil (8 bit) =", format(hasil_2026, '08b'))
# Out:
# ...
# 3. OPERATOR BITWISE
# ...
#
# Angka dalam bentuk desimal dan biner:
# Angka 1: 10 -| biner 0b1010
# Angka 2: 5 -| biner 0b101
#
# Bitwise AND (&)
# 10 & 5 = 0
# Biner hasil = 0b0
# Biner hasil (8 bit) = 00000000
#
# Bitwise OR (|)
# 10 | 5 = 15
# Biner hasil = 0b1111
# Biner hasil (8 bit) = 00001111
#
# Bitwise XOR (^)
# 10 ^ 5 = 15
# Biner hasil = 0b1111
# Biner hasil (8 bit) = 00001111
#
# Bitwise NOT (~)
# ~ 10 = -11
# Biner hasil = -0b1011
# Biner hasil (8 bit) = -0001011
#
# Bitwise Geser Kiri (<<)
# 10 << 2 = 40
# Biner hasil = 0b101000
# Biner hasil (8 bit) = 00101000
#
# Bitwise Geser Kanan (>>)
# 10 >> 2 = 2
# Biner hasil = 0b10
# Biner hasil (8 bit) = 00000010

# %% [markdown]
# **Penjelasan :**
#
# 1. **Bagian 1 sampai 3** berfungsi untuk menampilkan judul program yang menunjukkan bahwa kode membahas operator bitwise.
#
# 2. **Bagian 5 sampai 6** berfungsi untuk menerima dua angka dari pengguna yang akan digunakan dalam operasi bitwise.
#
# 3. **Bagian 8 sampai 10** berfungsi untuk menampilkan nilai kedua angka dalam bentuk desimal dan biner menggunakan fungsi `bin()`.
#
# 4. **Bagian 12 sampai 17** berfungsi untuk melakukan operasi Bitwise AND menggunakan operator `&`, kemudian menampilkan hasil operasi dalam bentuk desimal, biner, dan biner 8 bit.
#
# 5. **Bagian 19 sampai 24** berfungsi untuk melakukan operasi Bitwise OR menggunakan operator `|`, kemudian menampilkan hasil operasi dalam bentuk desimal, biner, dan biner 8 bit.
#
# 6. **Bagian 26 sampai 31** berfungsi untuk melakukan operasi Bitwise XOR menggunakan operator `^`, kemudian menampilkan hasil operasi dalam bentuk desimal, biner, dan biner 8 bit.
#
# 7. **Bagian 33 sampai 38** berfungsi untuk melakukan operasi Bitwise NOT menggunakan operator `~` terhadap `angka1_2026`, kemudian menampilkan hasil operasi dalam bentuk desimal, biner, dan biner 8 bit.
#
# 8. **Bagian 40 sampai 41** berfungsi untuk menentukan dan menerima jumlah pergeseran bit dari pengguna yang akan digunakan dalam operasi Bitwise geser kiri dan geser kanan.
#
# 9. **Bagian 43 sampai 47** berfungsi untuk melakukan operasi Bitwise geser kiri menggunakan operator `<<`, kemudian menampilkan hasil operasi dalam bentuk desimal, biner, dan biner 8 bit.
#
# 10. **Bagian 49 sampai 54** berfungsi untuk melakukan operasi Bitwise geser kanan menggunakan operator `>>`, kemudian menampilkan hasil operasi dalam bentuk desimal, biner, dan biner 8 bit.

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
#  Studi Kasus: Sistem Simulasi Transaksi dan Validasi Akses Toko
# Anda diminta untuk membuat sebuah program kasir sederhana yang digunakan untuk menghitung total transaksi pelanggan sekaligus melakukan pemeriksaan terhadap status pelanggan dan hak akses terhadap promo tertentu. Program menerima data transaksi dan informasi pelanggan, kemudian menggunakan berbagai jenis operator Python untuk menentukan total pembayaran, status diskon, kelayakan promo, serta hak akses pelanggan. Seluruh proses harus dibuat dalam satu alur program yang utuh.

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "tugas3_2611532026"

# %%
print("=== SISTEM TRANSAKSI TOKO ===")

nama_2026 = input("Masukkan Nama Pelanggan : ")
status_2026 = input("Masukkan Status Pelanggan (member/nonmember) : ").lower()
total_belanja_2026 = float(input("Masukkan Total Belanja : Rp"))
jumlah_barang_2026 = int(input("Masukkan Jumlah Barang : "))
kode_promo_2026 = input("Masukkan Kode Promo : ").upper()

syarat_belanja_2026 = total_belanja_2026 >= 200000
syarat_barang_2026 = jumlah_barang_2026 >= 3
status_member_2026 = status_2026 == "member"

daftar_promo_2026 = ["HEMAT10", "HEMAT20", "GRATISONGKIR"]

promo_tersedia_2026 = kode_promo_2026 in daftar_promo_2026
promo_tidak_tersedia_2026 = kode_promo_2026 not in daftar_promo_2026

diskon_member_2026 = status_member_2026 and syarat_belanja_2026

promo_didapatkan_2026 = promo_tersedia_2026 and (syarat_belanja_2026 or syarat_barang_2026)

bukan_member_2026 = not status_member_2026

if diskon_member_2026:
    persentase_diskon_2026 = 0.10
else:
    persentase_diskon_2026 = 0.05 if syarat_belanja_2026 else 0

besar_diskon_2026 = total_belanja_2026 * persentase_diskon_2026

total_pembayaran_2026 = total_belanja_2026 - besar_diskon_2026

if jumlah_barang_2026 > 0:
    rata_rata_barang_2026 = total_belanja_2026 / jumlah_barang_2026
else:
    rata_rata_barang_2026 = 0

sisa_pembagian_2026 = int(total_belanja_2026) % jumlah_barang_2026 if jumlah_barang_2026 > 0 else 0


poin_2026 = 0
if status_member_2026:
    poin_2026 += int(total_pembayaran_2026 // 10000)

jumlah_barang_tersisa_2026 = jumlah_barang_2026
if promo_didapatkan_2026:
    jumlah_barang_tersisa_2026 -= 1

kode_1_2026 = ["HEMAT10"]
kode_2_2026 = ["HEMAT10"]

nilai_sama_2026 = kode_1_2026 == kode_2_2026
objek_sama_2026 = kode_1_2026 is kode_2_2026
objek_berbeda_2026 = kode_1_2026 is not kode_2_2026


kode_member_2026 = 1 if status_member_2026 else 0
kode_belanja_2026 = 2 if syarat_belanja_2026 else 0
kode_barang_2026 = 4 if syarat_barang_2026 else 0
kode_promo_2026 = 8 if promo_tersedia_2026 else 0

# Operator OR (|)
kode_status_2026 = (
    kode_member_2026
    | kode_belanja_2026
    | kode_barang_2026
    | kode_promo_2026
)

cek_member_2026 = kode_status_2026 & 1
cek_belanja_2026 = kode_status_2026 & 2
cek_barang_2026 = kode_status_2026 & 4
cek_promo_2026 = kode_status_2026 & 8

kode_referensi_2026 = 11
perbandingan_status_2026 = kode_status_2026 ^ kode_referensi_2026

kode_shift_2026 = kode_status_2026 << 1


member_access_2026 = bool(cek_member_2026)
promo_access_2026 = bool(cek_promo_2026)
free_shipping_access_2026 = syarat_belanja_2026 and syarat_barang_2026


print("\n=== DATA PELANGGAN ===")
print("Nama Pelanggan       :", nama_2026)
print("Status Pelanggan     :", status_2026)
print("Total Belanja        : Rp", total_belanja_2026)
print("Jumlah Barang        :", jumlah_barang_2026)
print("Kode Promo           :", kode_promo_2026)


print("\n=== HASIL VALIDASI ===")
print("Belanja >= Rp200000  :", syarat_belanja_2026)
print("Jumlah Barang >= 3   :", syarat_barang_2026)
print("Status Member        :", status_member_2026)
print("Kode Promo Tersedia  :", promo_tersedia_2026)
print("Mendapatkan Diskon   :", diskon_member_206)
print("Mendapatkan Promo    :", promo_didapatkan_2026)


print("\n=== HASIL PERHITUNGAN ===")
print("Besarnya Diskon      : Rp", besar_diskon_2026)
print("Total Pembayaran     : Rp", total_pembayaran_2026)
print("Rata-rata Harga      : Rp", rata_rata_barang_2026)
print("Sisa Pembagian       :", sisa_pembagian_2026)


print("\n=== HAK AKSES PELANGGAN ===")
print("Kode Hak Akses       :", format(kode_status_2026, "04b"))
print("Member Access        :", member_access_2026)
print("Promo Access         :", promo_access_2026)
print("Free Shipping Access :", free_shipping_access_2026)
print("Poin Pelanggan       :", poin_2026)


print("\n=== OPERATOR IDENTITAS ===")
print("kode_1 == kode_2     :", nilai_sama_2026)
print("kode_1 is kode_2     :", objek_sama_2026)
print("kode_1 is not kode_2 :", objek_berbeda_2026)


print("\n=== OPERASI BITWISE ===")
print("Kode Status Transaksi")
print("0001 | 0010 | 0100 | 1000")

print("Kode Biner           :", format(kode_status_2026, "04b"))
print("Kode Desimal         :", kode_status_2026)

print("\n=== PEMERIKSAAN STATUS ===")

print("\nCek Member")
print(format(kode_status_2026, "04b"), "& 0001")
print("Hasil Biner         :", format(cek_member_2026, "04b"))
print("Hasil Desimal       :", cek_member_2026)

print("\nCek Belanja")
print(format(kode_status_2026, "04b"), "& 0010")
print("Hasil Biner         :", format(cek_belanja_2026, "04b"))
print("Hasil Desimal       :", cek_belanja_2026)

print("\nCek Jumlah Barang")
print(format(kode_status_2026, "04b"), "& 0100")
print("Hasil Biner         :", format(cek_barang_2026, "04b"))
print("Hasil Desimal       :", cek_barang_2026)

print("\nCek Promo")
print(format(kode_status_2026, "04b"), "& 1000")
print("Hasil Biner         :", format(cek_promo_2026, "04b"))
print("Hasil Desimal       :", cek_promo_2026)

print("\n=== PERBANDINGAN STATUS (XOR) ===")
print("Kode Transaksi      :", format(kode_status_2026, "04b"))
print("Kode Referensi      :", format(kode_referensi_2026, "04b"))
print(format(kode_status_2026, "04b"), "^",
      format(kode_referensi_2026, "04b"))
print("Hasil Biner         :", format(perbandingan_status_2026, "04b"))
print("Hasil Desimal       :", perbandingan_status_2026)

print("\n=== SHIFT ===")
print(format(kode_status_2026, "04b"), "<< 1")
print("Hasil Biner         :", format(kode_shift_2026, "b"))
print("Hasil Desimal       :", kode_shift_2026)

print("\n=== SELESAI ===")
# Out:
# === SISTEM TRANSAKSI TOKO ===
#
# === DATA PELANGGAN ===
# Nama Pelanggan       : Yuan
# Status Pelanggan     : member
# Total Belanja        : Rp 300000.0
# Jumlah Barang        : 5
# Kode Promo           : 8
#
# === HASIL VALIDASI ===
# Belanja >= Rp200000  : True
# Jumlah Barang >= 3   : True
# Status Member        : True
# Kode Promo Tersedia  : True
# Mendapatkan Diskon   : True
# Mendapatkan Promo    : True
#
# === HASIL PERHITUNGAN ===
# Besarnya Diskon      : Rp 30000.0
# Total Pembayaran     : Rp 270000.0
# Rata-rata Harga      : Rp 60000.0
# Sisa Pembagian       : 0
#
# === HAK AKSES PELANGGAN ===
# Kode Hak Akses       : 1111
# Member Access        : True
# Promo Access         : True
# Free Shipping Access : True
# Poin Pelanggan       : 27
#
# === OPERATOR IDENTITAS ===
# kode_1 == kode_2     : True
# kode_1 is kode_2     : False
# kode_1 is not kode_2 : True
#
# === OPERASI BITWISE ===
# Kode Status Transaksi
# 0001 | 0010 | 0100 | 1000
# Kode Biner           : 1111
# ...

# %% [markdown]
# **Penjelasan :**
# 1. Jelaskan operator aritmatika apa saja yang digunakan dan bagaimana operator tersebut membantu menghitung transaksi.
#
# Program menggunakan beberapa operator aritmatika, yaitu perkalian (*) untuk menghitung besar diskon, pengurangan (-) untuk menghitung total pembayaran setelah diskon, pembagian (/) untuk menghitung rata-rata harga barang, pembagian bulat (//) untuk menghitung poin pelanggan, dan modulus (%) untuk mendapatkan sisa pembagian total belanja dengan jumlah barang. Operator tersebut digunakan agar perhitungan transaksi dapat dilakukan secara otomatis berdasarkan input pengguna.
#
# 2. Jelaskan perbedaan operator and, or, dan not berdasarkan penerapannya pada program.
#
# Operator and menghasilkan True apabila semua kondisi yang digabungkan bernilai True. Dalam program, and digunakan untuk menentukan apakah member yang memenuhi minimum belanja mendapatkan diskon. Operator or menghasilkan True apabila minimal salah satu kondisi bernilai True, misalnya ketika memeriksa syarat promo. Operator not digunakan untuk membalik nilai Boolean, contohnya not status_member_3003 menghasilkan True ketika pelanggan bukan member.
#
# 3. Jelaskan fungsi operator in dan not in pada pemeriksaan kode promo.
#
# Operator in digunakan untuk memeriksa apakah suatu kode promo terdapat di dalam daftar promo yang tersedia. Jika kode ditemukan, hasilnya True. Sebaliknya, not in digunakan untuk memeriksa apakah kode promo tidak terdapat dalam daftar. Contohnya, HEMAT10 in daftar_promo_3003 menghasilkan True.
#
# 4. Apa perbedaan antara is dan == pada Python?
#
# == digunakan untuk membandingkan nilai atau isi dari dua objek, sedangkan is digunakan untuk membandingkan identitas objek, yaitu apakah dua variabel menunjuk pada objek yang sama. Pada program, dua list dapat mempunyai isi yang sama sehingga == bernilai True, tetapi tetap merupakan objek yang berbeda sehingga is bernilai False.
#
# 5. Jelaskan bagaimana operator bitwise digunakan untuk menentukan hak akses pelanggan.
#
# Setiap kondisi pelanggan direpresentasikan dengan satu bit. 0001 menunjukkan member, 0010 menunjukkan belanja minimal Rp200.000, 0100 menunjukkan jumlah barang minimal 3, dan 1000 menunjukkan kode promo tersedia. Operator OR (|) digunakan untuk menggabungkan kondisi tersebut menjadi satu kode status. Operator AND (&) digunakan untuk memeriksa bit tertentu sehingga hak akses pelanggan dapat diketahui. Operator XOR (^) digunakan untuk membandingkan kode transaksi dengan kode referensi.
#
# 6. Jelaskan alur program mulai dari input hingga menghasilkan total pembayaran dan status promo.
#
# Program dimulai dengan meminta nama, status pelanggan, total belanja, jumlah barang, dan kode promo. Data tersebut kemudian digunakan untuk melakukan perbandingan terhadap syarat minimum belanja, jumlah barang, status member, dan ketersediaan promo. Kondisi-kondisi tersebut digabungkan menggunakan operator logika untuk menentukan diskon dan promo. Setelah itu program menghitung besar diskon, total pembayaran, rata-rata harga barang, dan poin pelanggan. Selanjutnya kondisi pelanggan diubah menjadi kode bitwise untuk menentukan hak akses dan menampilkan hasil seluruh operator.
#
# 7. Identifikasi minimal satu kondisi dalam program yang menghasilkan True dan satu kondisi yang menghasilkan False.
#
# Contoh kondisi True adalah:
#
# total_belanja_2026 >= 200000
#
# jika total belanja Rp250.000, hasilnya True.
#
# Contoh kondisi False adalah:
#
# jumlah_barang_2026 >= 3
#
# jika pelanggan membeli 2 barang, hasilnya False.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa operator merupakan salah satu bagian penting dalam bahasa pemrograman Python yang digunakan untuk melakukan berbagai operasi terhadap data dan variabel. Python memiliki beberapa jenis operator, yaitu operator aritmatika, assignment, perbandingan, logika, membership, identity, dan bitwise.
#
# Setiap operator memiliki fungsi yang berbeda. Operator aritmatika digunakan untuk melakukan perhitungan matematika, operator assignment untuk memberikan dan mengubah nilai variabel, operator perbandingan untuk membandingkan nilai, serta operator logika untuk menggabungkan kondisi. Operator membership digunakan untuk memeriksa keberadaan suatu nilai dalam koleksi, operator identity digunakan untuk memeriksa identitas objek, sedangkan operator bitwise digunakan untuk melakukan operasi pada tingkat bit.
#
# Melalui praktikum ini, penggunaan berbagai jenis operator dapat dipahami dan diterapkan secara langsung menggunakan program Python. Pemahaman terhadap operator menjadi dasar penting untuk membuat program yang lebih kompleks dan terstruktur.

# %% [markdown]
# # SARAN
# Sebaiknya praktikan lebih sering melakukan latihan menggunakan berbagai jenis operator Python agar dapat memahami fungsi dan cara penggunaannya dengan lebih baik. Praktikan juga perlu memperhatikan penulisan sintaks karena kesalahan kecil dalam penulisan kode dapat menyebabkan program menghasilkan kesalahan (error).
#
# Selain itu, praktikan disarankan untuk mencoba membuat program sederhana dengan menggabungkan beberapa jenis operator, sehingga pemahaman mengenai penggunaan operator dalam kondisi nyata dapat semakin meningkat.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Python Software Foundation, “Built-in Types,” Python Documentation, 2026. [Online]. Tersedia: https://docs.python.org/3/library/stdtypes.html [Diakses 17 September 2026].
#
# [2] Python Software Foundation, “Expressions — Python 3 Documentation,” Python Documentation, 2026. [Online]. Tersedia: https://docs.python.org/3/reference/expressions.html [Diakses 17 September 2026].
#
# [3] Python Software Foundation, “More Control Flow Tools,” Python Documentation, 2026. [Online]. Tersedia: https://docs.python.org/3/tutorial/controlflow.html [Diakses 17 September 2026].
